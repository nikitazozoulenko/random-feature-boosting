# %%
from typing import Tuple, List, Union, Any, Optional, Dict, Literal, Callable
import time
import collections
import os
import sys
sys.path.append(os.path.dirname(os.getcwd()))
sys.path.append(os.path.dirname(os.path.dirname(os.getcwd())))

from tqdm import tqdm
import numpy as np
import torch
import torch.nn as nn
from torch import Tensor
import pandas as pd
import openml

from optuna_kfoldCV import evaluate_dataset_with_model, run_all_openML_with_model
from regression_param_specs import evaluate_GRFBoost, evaluate_Ridge, evaluate_XGBoostRegressor

np.set_printoptions(precision=3, threshold=5) # Print options

# %% [markdown]
# # OpenML code

# %%
# Fetch the collection with ID 353
collection = openml.study.get_suite(353)
dataset_ids = collection.data
metadata_list = []

# Fetch and process each dataset
for i, dataset_id in enumerate(dataset_ids):
    dataset = openml.datasets.get_dataset(dataset_id)
    X, y, categorical_indicator, attribute_names = dataset.get_data(
        target=dataset.default_target_attribute
    )

    #count missing values in X
    missing_values_count = X.isnull().sum().sum()
    print(f"Missing values in X: {missing_values_count}")

    X = np.array(X)
    y = np.array(y)[..., None]
    print(X.shape)
    print(y.shape)
    
    # Determine if the dataset has categorical features
    has_categorical = any(categorical_indicator)
    
    # Extract the required metadata
    metadata = {
        'dataset_id': dataset.id,
        'name': dataset.name,
        'n_obs': int(dataset.qualities['NumberOfInstances']),
        'n_features': int(dataset.qualities['NumberOfFeatures']),
        '%_unique_y': len(np.unique(y))/len(y),
        'n_unique_y': len(np.unique(y)),
        'has_categorical': has_categorical,
        'n_missing_values': missing_values_count,
    }
    
    metadata_list.append(metadata)
    print(f" {i+1}/{len(dataset_ids)} Processed dataset {dataset.id}: {dataset.name}")

# Create a DataFrame from the metadata list
df_metadata = pd.DataFrame(metadata_list).sort_values('%_unique_y', ascending=False).set_index("dataset_id").sort_index()
df_metadata.sort_values('%_unique_y', ascending=True)

# Display the metadata DataFrame
df_metadata.loc[44962, "has_categorical"] = True
df_metadata
# Out:
# Missing values in X: 0
# (4177, 8)
# (4177, 1)
#  1/35 Processed dataset 44956: abalone
# Missing values in X: 0
# (1503, 5)
# (1503, 1)
#  2/35 Processed dataset 44957: airfoil_self_noise
# Missing values in X: 0
# (2043, 7)
# (2043, 1)
#  3/35 Processed dataset 44958: auction_verification
# Missing values in X: 0
# (1030, 8)
# (1030, 1)
#  4/35 Processed dataset 44959: concrete_compressive_strength
# Missing values in X: 0
# (45730, 9)
# (45730, 1)
#  5/35 Processed dataset 44963: physiochemical_protein
# Missing values in X: 0
# (21263, 81)
# (21263, 1)
#  6/35 Processed dataset 44964: superconductivity
# Missing values in X: 0
# (1059, 116)
# (1059, 1)
#  7/35 Processed dataset 44965: geographical_origin_of_music
# Missing values in X: 0
# (1066, 10)
# (1066, 1)
#  8/35 Processed dataset 44966: solar_flare
# Missing values in X: 0
# (11934, 14)
# (11934, 1)
#  9/35 Processed dataset 44969: naval_propulsion_plant
# Missing values in X: 0
# (4898, 11)
# (4898, 1)
#  10/35 Processed dataset 44971: white_wine
# Missing values in X: 0
# (1599, 11)
# (1599, 1)
#  11/35 Processed dataset 44972: red_wine
# Missing values in X: 0
# (10000, 12)
# (10000, 1)
#  12/35 Processed dataset 44973: grid_stability
# Missing values in X: 0
# (68784, 18)
# (68784, 1)
#  13/35 Processed dataset 44974: video_transcoding
# Missing values in X: 0
# (72000, 48)
# (72000, 1)
#  14/35 Processed dataset 44975: wave_energy
# Missing values in X: 0
# (48933, 21)
# (48933, 1)
#  15/35 Processed dataset 44976: sarcos
# Missing values in X: 0
# (20640, 8)
# (20640, 1)
#  16/35 Processed dataset 44977: california_housing
# Missing values in X: 0
# (8192, 21)
# (8192, 1)
#  17/35 Processed dataset 44978: cpu_activity
# Missing values in X: 0
# (53940, 9)
# (53940, 1)
#  18/35 Processed dataset 44979: diamonds
# Missing values in X: 0
# (8192, 8)
# (8192, 1)
#  19/35 Processed dataset 44980: kin8nm
# Missing values in X: 0
# (8192, 32)
# (8192, 1)
#  20/35 Processed dataset 44981: pumadyn32nh
# Missing values in X: 0
# (13932, 15)
# (13932, 1)
#  21/35 Processed dataset 44983: miami_housing
# Missing values in X: 0
# (28155, 6)
# (28155, 1)
#  22/35 Processed dataset 44984: cps88wages
# Missing values in X: 0
# (1156, 5)
# (1156, 1)
#  23/35 Processed dataset 44987: socmob
# Missing values in X: 0
# (21613, 21)
# (21613, 1)
#  24/35 Processed dataset 44989: kings_county
# Missing values in X: 0
# (10692, 9)
# (10692, 1)
#  25/35 Processed dataset 44990: brazilian_houses
# Missing values in X: 69696
# (24624, 43)
# (24624, 1)
#  26/35 Processed dataset 44992: fps_benchmark
# Missing values in X: 0
# (22272, 11)
# (22272, 1)
#  27/35 Processed dataset 44993: health_insurance
# Missing values in X: 0
# (19178, 28)
# (19178, 1)
#  28/35 Processed dataset 45012: fifa
# Missing values in X: 3600
# (1232, 14)
# (1232, 1)
#  29/35 Processed dataset 41021: Moneyball
# Missing values in X: 0
# (768, 8)
# (768, 1)
#  30/35 Processed dataset 44960: energy_efficiency
# Missing values in X: 0
# (517, 12)
# (517, 1)
#  31/35 Processed dataset 44962: forest_fires
# Missing values in X: 0
# (649, 30)
# (649, 1)
#  32/35 Processed dataset 44967: student_performance_por
# Missing values in X: 0
# (908, 6)
# (908, 1)
#  33/35 Processed dataset 44970: QSAR_fish_toxicity
# Missing values in X: 0
# (804, 17)
# (804, 1)
#  34/35 Processed dataset 44994: cars
# Missing values in X: 0
# (3107, 6)
# (3107, 1)
#  35/35 Processed dataset 45402: space_ga
#                                      name  n_obs  n_features  %_unique_y  \
# dataset_id
# 41021                           Moneyball   1232          15    0.303571
# 44956                             abalone   4177           9    0.006703
# 44957                  airfoil_self_noise   1503           6    0.968729
# 44958                auction_verification   2043           8    0.998042
# 44959       concrete_compressive_strength   1030           9    0.910680
# 44960                   energy_efficiency    768           9    0.764323
# 44962                        forest_fires    517          13    0.485493
# 44963              physiochemical_protein  45730          10    0.347759
# 44964                   superconductivity  21263          82    0.141419
# 44965        geographical_origin_of_music   1059         117    0.029273
# 44966                         solar_flare   1066          11    0.007505
# 44967             student_performance_por    649          31    0.026194
# 44969              naval_propulsion_plant  11934          15    0.004274
# 44970                  QSAR_fish_toxicity    908           7    0.910793
# 44971                          white_wine   4898          12    0.001429
# 44972                            red_wine   1599          12    0.003752
# 44973                      grid_stability  10000          13    1.000000
# 44974                   video_transcoding  68784          19    0.159339
# 44975                         wave_energy  72000          49    0.999903
# 44976                              sarcos  48933          22    0.233258
# 44977                  california_housing  20640           9    0.186143
# 44978                        cpu_activity   8192          22    0.006836
# 44979                            diamonds  53940          10    0.215091
# 44980                              kin8nm   8192           9    0.999878
# 44981                         pumadyn32nh   8192          33    0.999878
# 44983                       miami_housing  13932          16    0.151522
# 44984                          cps88wages  28155           7    0.212040
# 44987                              socmob   1156           6    0.312284
# 44989                        kings_county  21613          22    0.186369
# 44990                    brazilian_houses  10692          10    0.537879
# 44992                       fps_benchmark  24624          44    0.108634
# 44993                    health_insurance  22272          12    0.003367
# 44994                                cars    804          18    0.992537
# 45012                                fifa  19178          29    0.006935
# 45402                            space_ga   3107           7    0.999356
#
#             n_unique_y  has_categorical  n_missing_values
# dataset_id
# 41021              374             True              3600
# 44956               28             True                 0
# 44957             1456            False                 0
# 44958             2039             True                 0
# 44959              938            False                 0
# 44960              587            False                 0
# 44962              251             True                 0
# 44963            15903            False                 0
# 44964             3007            False                 0
# 44965               31            False                 0
# 44966                8             True                 0
# 44967               17             True                 0
# 44969               51            False                 0
# 44970              827            False                 0
# 44971                7            False                 0
# 44972                6            False                 0
# 44973            10000            False                 0
# 44974            10960             True                 0
# 44975            71993            False                 0
# 44976            11414            False                 0
# 44977             3842            False                 0
# 44978               56            False                 0
# 44979            11602             True                 0
# 44980             8191            False                 0
# 44981             8191            False                 0
# 44983             2111            False                 0
# 44984             5970             True                 0
# 44987              361             True                 0
# 44989             4028             True                 0
# 44990             5751             True                 0
# 44992             2675             True             69696
# 44993               75             True                 0
# 44994              798            False                 0
# 45012              133             True                 0
# 45402             3105            False                 0

# %%
dataset_ids_no_categorical = list(df_metadata.query("has_categorical == False").index.values)
dataset_ids_no_categorical = sorted([int(x) for x in dataset_ids_no_categorical])
len(dataset_ids_no_categorical)
dataset_ids_no_categorical
# Out:
# [44957,
#  44959,
#  44960,
#  44963,
#  44964,
#  44965,
#  44969,
#  44970,
#  44971,
#  44972,
#  44973,
#  44975,
#  44976,
#  44977,
#  44978,
#  44980,
#  44981,
#  44983,
#  44994,
#  45402]

# %% [markdown]
# # Run experiments (just for testing)

# %%
run_all_openML_with_model(
    dataset_ids_no_categorical[0:2], 
    evaluate_Ridge,
    name_model="Ridge",
    k_folds=5,
    cv_seed=42,
    regression_or_classification="regression",
    n_optuna_trials=2,
    device="cuda",
    save_dir = "/home/nikita/Code/zephyrox/pytorch_based/SWIM/save/"
)
# Out:
# [I 2024-11-25 11:03:37,696] A new study created in memory with name: no-name-7e6c082b-99a0-4ca1-b92e-b5429f9b02db
# [I 2024-11-25 11:03:37,731] Trial 0 finished with value: 0.6950941801071167 and parameters: {'l2_reg': 4.770460224451055e-07}. Best is trial 0 with value: 0.6950941801071167.
# [I 2024-11-25 11:03:37,738] Trial 1 finished with value: 0.6950941801071167 and parameters: {'l2_reg': 1.4210086053412847e-05}. Best is trial 0 with value: 0.6950941801071167.
# [I 2024-11-25 11:03:37,938] Trial 1 finished with value: 0.5809296727180481 and parameters: {'l2_reg': 1.6951931313358376e-05}. Best is trial 0 with value: 0.5809270977973938.
# [I 2024-11-25 11:03:37,941] A new study created in memory with name: no-name-13079c84-e08d-4f0a-b91c-8778c747c42f
# [I 2024-11-25 11:03:37,946] Trial 0 finished with value: 0.6025380253791809 and parameters: {'l2_reg': 1.0759188458473238e-07}. Best is trial 0 with value: 0.6025380253791809.
# [I 2024-11-25 11:03:37,950] Trial 1 finished with value: 0.6025377869606018 and parameters: {'l2_reg': 0.004885747986945916}. Best is trial 1 with value: 0.6025377869606018.
# [I 2024-11-25 11:03:37,952] A new study created in memory with name: no-name-ef92681a-41f6-4f6e-b680-6091226172b4
# [I 2024-11-25 11:03:37,957] Trial 0 finished with value: 0.5873180747032165 and parameters: {'l2_reg': 0.00018198720851197198}. Best is trial 0 with value: 0.5873180747032165.
# [I 2024-11-25 11:03:37,961] Trial 1 finished with value: 0.5873180627822876 and parameters: {'l2_reg': 5.315167951275965e-07}. Best is trial 1 with value: 0.5873180627822876.
#  1/2 Processed dataset 44957
#  2/2 Processed dataset 44959
# {'44957': {'Ridge': {'score_train': [0.6904380321502686,
#     0.6888523101806641,
#     0.690494954586029,
#     0.6793413758277893,
#     0.6790646910667419],
#    'score_test': [0.6714187264442444,
#     0.6768081784248352,
#     0.6710893511772156,
#     0.7160781025886536,
#     0.7178991436958313],
#    't_fit': [0.0014943280002626125,
#     0.0007019670001682243,
#     0.0008961670000644517,
#     0.00687843800005794,
#     0.0005899299994780449],
#    't_inference': [8.147500011546072e-05,
#     6.105400007072603e-05,
#     6.80860002830741e-05,
#     7.047199960652506e-05,
#     4.3855000512849074e-05],
#    'hyperparams': [{'l2_reg': 4.770460224451055e-07},
#     {'l2_reg': 3.692257350103396e-07},
#     {'l2_reg': 0.012303607322394005},
#     {'l2_reg': 1.0422206015206492e-05},
#     {'l2_reg': 0.00042002862208719694}]}},
#  '44959': {'Ridge': {'score_train': [0.5919755101203918,
#     0.5584654808044434,
#     0.5737617611885071,
#     0.5931828022003174,
#     0.5818951725959778],
#    'score_test': [0.5422646403312683,
#     0.6703803539276123,
#     0.6134750843048096,
#     0.5358847975730896,
#     0.5826089382171631],
#    't_fit': [0.0006438330001401482,
#     0.0006400319998647319,
#     0.000690198000484088,
#     0.0006699619998471462,
#     0.0006813770005464903],
#    't_inference': [5.476200021803379e-05,
#     4.896599966741633e-05,
#     7.118699977581855e-05,
#     4.166100006841589e-05,
#     4.11789997087908e-05],
#    'hyperparams': [{'l2_reg': 0.002131596153656544},
#     {'l2_reg': 4.062250273399671e-06},
#     {'l2_reg': 0.013155994200054822},
#     {'l2_reg': 0.004885747986945916},
#     {'l2_reg': 5.315167951275965e-07}]}}}

# %%
run_all_openML_with_model(
    dataset_ids_no_categorical[0:2], 
    evaluate_GRFBoost,
    name_model="GRFBoost",
    k_folds=5,
    cv_seed=42,
    regression_or_classification="regression",
    n_optuna_trials=2,
    device="cuda",
    save_dir = "/home/nikita/Code/zephyrox/pytorch_based/SWIM/save/"
)
# Out:
# [I 2024-11-25 11:03:37,985] A new study created in memory with name: no-name-add3a45d-ab4d-4687-adeb-43b13e38bf25
# [I 2024-11-25 11:03:38,154] Trial 0 finished with value: 0.502512264251709 and parameters: {'out_dim': 1, 'feature_type': 'SWIM', 'upscale': 'dense', 'hidden_dim':
#  2/2 Processed dataset 44959
# {'44957': {'GRFBoost': {'score_train': [0.47585028409957886,
#     0.4695267677307129,
#     0.4265369474887848,
#     0.45623016357421875,
#     0.43326061964035034],
#    'score_test': [0.4703754782676697,
#     0.47517815232276917,
#     0.4415760636329651,
#     0.5007573366165161,
#     0.4916688799858093],
#    't_fit': [0.0343653740001173,
#     0.014975527999922633,
#     0.10601014499934536,
#     0.018334454999603622,
#     0.056702144000155386],
#    't_inference': [0.0033401739992768853,
#     0.0010968409997076378,
#     0.00960470400059421,
#     0.0011972720003541326,
#     0.0038464350000140257],
#    'hyperparams': [{'out_dim': 1,
#      'feature_type': 'SWIM',
#      'upscale': 'dense',
#      'hidden_dim': 5,
#      'bottleneck_dim': 97,
#      'n_layers': 6,
#      'l2_reg': 0.02898469778422591,
#      'boost_lr': 0.18768074232656476},
#     {'out_dim': 1,
#      'feature_type': 'SWIM',
#      'upscale': 'dense',
#      'hidden_dim': 39,
#      'bottleneck_dim': 70,
#      'n_layers': 2,
#      'l2_reg': 0.0009039930010732471,
#      'boost_lr': 0.3627591479475786},
#     {'out_dim': 1,
#      'feature_type': 'SWIM',
#      'upscale': 'dense',
#      'hidden_dim': 27,
#      'bottleneck_dim': 89,
#      'n_layers': 19,
#      'l2_reg': 0.0011499656946655481,
#      'boost_lr': 0.7576783936271145},
#     {'out_dim': 1,
#      'feature_type': 'SWIM',
#      'upscale': 'dense',
#      'hidden_dim': 31,
#      'bottleneck_dim': 91,
#      'n_layers': 3,
#      'l2_reg': 3.0183871803971207e-05,
#      'boost_lr': 0.26719561099464006},
#     {'out_dim': 1,
#      'feature_type': 'SWIM',
#      'upscale': 'dense',
#      'hidden_dim': 26,
#      'bottleneck_dim': 108,
#      'n_layers': 8,
#      'l2_reg': 0.0015753479810380671,
#      'boost_lr': 0.5353065721956886}]}},
#  '44959': {'GRFBoost': {'score_train': [0.34761014580726624,
#     0.28159472346305847,
#     0.2997439205646515,
#     0.2896016836166382,
#     0.33147844672203064],
#    'score_test': [0.36098799109458923,
#     0.37114736437797546,
#     0.37938496470451355,
#     0.3656527101993561,
#     0.38778069615364075],
#    't_fit': [0.016566792999583413,
#     0.18280110100022284,
#     0.020021831000121892,
#     0.13851482099926216,
#     0.11749556399990979],
#    't_inference': [0.0012460680000003777,
#     0.015810750000127882,
#     0.0025575889994797762,
#     0.01119138100057171,
#     0.00998724199962453],
#    'hyperparams': [{'out_dim': 1,
#      'feature_type': 'SWIM',
#      'upscale': 'dense',
#      'hidden_dim': 31,
#      'bottleneck_dim': 91,
#      'n_layers': 4,
#      'l2_reg': 4.1839106172508574e-05,
#      'boost_lr': 0.18883815575792723},
#     {'out_dim': 1,
#      'feature_type': 'SWIM',
#      'upscale': 'dense',
#      'hidden_dim': 58,
#      'bottleneck_dim': 124,
#      'n_layers': 31,
#      'l2_reg': 0.0002871676970166237,
#      'boost_lr': 0.11839161496318014},
#     {'out_dim': 1,
#      'feature_type': 'SWIM',
#      'upscale': 'dense',
#      'hidden_dim': 77,
#      'bottleneck_dim': 123,
#      'n_layers': 2,
#      'l2_reg': 0.0006533472557900826,
#      'boost_lr': 0.7795048892726716},
#     {'out_dim': 1,
#      'feature_type': 'SWIM',
#      'upscale': 'dense',
#      'hidden_dim': 16,
#      'bottleneck_dim': 108,
#      'n_layers': 30,
#      'l2_reg': 0.0005144297552435775,
#      'boost_lr': 0.7386965181494246},
#     {'out_dim': 1,
#      'feature_type': 'SWIM',
#      'upscale': 'dense',
#      'hidden_dim': 28,
#      'bottleneck_dim': 100,
#      'n_layers': 33,
#      'l2_reg': 8.089369324851717e-06,
#      'boost_lr': 0.51359244846458}]}}}

# %%
run_all_openML_with_model(
    dataset_ids_no_categorical[0:2], 
    evaluate_XGBoostRegressor,
    name_model="XGBoost",
    k_folds=5,
    cv_seed=42,
    regression_or_classification="regression",
    n_optuna_trials=2,
    device="cuda",
    save_dir = "/home/nikita/Code/zephyrox/pytorch_based/SWIM/save/"
)
# Out:
# [I 2024-11-25 11:03:43,523] A new study created in memory with name: no-name-c44e772d-6b36-4c73-bcf3-04577d7f9148
# [I 2024-11-25 11:03:43,886] Trial 0 finished with value: 0.6167511105537414 and parameters: {'objective': 'reg:squarederror', 'lambda': 0.05452469009316798, 'learning_rate': 0.012785943639332416, 'n_estimators': 86, 'max_depth': 9, 'subsample': 0.8661561259409865, 'colsample_bytree': 0.6675369549054682}. Best is trial 0 with value: 0.6167511105537414.
# [I 2024-11-25 11:03:44,176] Trial 1 finished with value: 0.2555988609790802 and parameters: {'objective': 'reg:squarederror', 'lambda': 0.06436044092893864, 'learning_rate': 0.10548019940205561, 'n_estimators': 179, 'max_depth': 6, 'subsample': 0.7874459483961107, 'colsample_bytree': 0.9359840421044765}. Best is trial 1 with value: 0.2555988609790802.
# [I 2024-11-25 11:03:44,241] A new study created in memory with name: no-name-a0164860-f388-470f-a70c-3d665cf1d01b
# [I 2024-11-25 11:03:45,087] Trial 0 finished with value: 0.2945442199707031 and parameters: {'objective': 'reg:squarederror', 'lambda': 0.005610204576382474, 'learning_rate': 0.01571876388948241, 'n_estimators': 194, 'max_depth': 10, 'subsample': 0.622086091542503, 'colsample_bytree': 0.9579219769567477}. Best is trial 0 with value: 0.2945442199707031.
# [I 2024-11-25 11:03:45,340] Trial 1 finished with value: 0.3418778896331787 and parameters: {'objective': 'reg:squarederror', 'lambda': 0.0035120365456419345, 'learning_rate': 0.11658080669769692, 'n_estimators': 270, 'max_depth': 3, 'subsample': 0.9207594571834992, 'colsample_bytree': 0.6671047947340931}. Best is trial 0 with value: 0.2945442199707031.
# [I 2024-11-25 11:03:45,589] A new study created in memory with name: no-name-3b1e8788-f2e0-48c6-98ae-d016c9210e75
# [I 2024-11-25 11:03:46,135] Trial 0 finished with value: 0.2972350776195526 and parameters: {'objective': 'reg:squarederror', 'lambda': 0.09191037112657982, 'learning_rate': 0.0446083786371968, 'n_estimators': 209, 'max_depth': 8, 'subsample': 0.9285835181426436, 'colsample_bytree': 0.7573043600206597}. Best is trial 0 with value: 0.2972350776195526.
# [I 2024-11-25 11:03:47,084] Trial 1 finished with value: 0.25632404088974 and parameters: {'objective': 'reg:squarederror', 'lambda': 0.2141549249607652, 'learning_rate': 0.04036810717031493, 'n_estimators': 200, 'max_depth': 10, 'subsample': 0.8122730811236298, 'colsample_bytree': 0.9036453635842872}. Best is trial 1 with value: 0.25632404088974.
# [I 2024-11-25 11:03:47,273] A new study created in memory with name: no-name-64b57116-f96f-4e02-a92a-55af44ff7cc9
# [I 2024-11-25 11:03:48,084] Trial 0 finished with value: 0.3231577634811401 and parameters: {'objective': 'reg:squarederror', 'lambda': 0
and parameters: {'objective': 'reg:squarederror', 'lambda': 0.003791199721383897, 'learning_rate': 0.021477534672509426, 'n_estimators': 186, 'max_depth': 8, 'subsample': 0.5681049504991935, 'colsample_bytree': 0.7045392410340755}. Best is trial 1 with value: 0.3043283998966217.
# [I 2024-11-25 11:03:52,205] A new study created in memory with name: no-name-0fef63d5-77b4-496e-8816-8d03ca696207
# [I 2024-11-25 11:03:53,123] Trial 0 finished with value: 0.28181780576705934 and parameters: {'objective': 'reg:squarederror', 'lambda': 4.097816585494131, 'learning_rate': 0.14302123585377594, 'n_estimators': 235, 'max_depth': 8, 'subsample': 0.6029669544031555, 'colsample_bytree': 0.7320094496849403}. Best is trial 0 with value: 0.28181780576705934.
# [I 2024-11-25 11:03:53,682] Trial 1 finished with value: 0.40353232622146606 and parameters: {'objective': 'reg:squarederror', 'lambda': 0.0030026875569099877, 'learning_rate': 0.0115364446632171, 'n_estimators': 206, 'max_depth': 6, 'subsample': 0.6591805253665038, 'colsample_bytree': 0.5116652744579655}. Best is trial 0 with value: 0.28181780576705934.
# [I 2024-11-25 11:03:53,915] A new study created in memory with name: no-name-bc3de0a1-5cbc-43e9-8fd8-3c958957dc7e
# [I 2024-11-25 11:03:54,778] Trial 0 finished with value: 0.26800850331783294 and parameters: {'objective': 'reg:squarederror', 'lambda': 0.5493569455577606, 'learning_rate': 0.06424387591365195, 'n_estimators': 294, 'max_depth': 7, 'subsample': 0.6386165448773796, 'colsample_bytree': 0.5602703675738538}. Best is trial 0 with value: 0.26800850331783294.
# [I 2024-11-25 11:03:54,917] Trial 1 finished with value: 0.38023775815963745 and parameters: {'objective': 'reg:squarederror', 'lambda': 0.09770841919115933, 'learning_rate': 0.04426635795438091, 'n_estimators': 94, 'max_depth': 3, 'subsample': 0.719629159114124, 'colsample_bytree': 0.7413363934079269}. Best is trial 0 with value: 0.26800850331783294.
#  2/2 Processed dataset 44959
# {'44957': {'XGBoost': {'score_train': [0.09720489382743835,
#     0.12964589893817902,
#     0.061221685260534286,
#     0.03712787106633186,
#     0.1342189610004425],
#    'score_test': [0.23469944298267365,
#     0.2275925874710083,
#     0.23300482332706451,
#     0.24160225689411163,
#     0.30334922671318054],
#    't_fit': [0.057530427000529016,
#     0.23463043599986122,
#     0.1763638810007251,
#     0.16610003000005236,
#     0.036808136999752605],
#    't_inference': [0.002540259999477712,
#     0.006157441000141262,
#     0.0060171789991727564,
#     0.004987080000319111,
#     0.0024545870001020376],
#    'hyperparams': [{'objective': 'reg:squarederror',
#      'lambda': 0.06436044092893864,
#      'learning_rate': 0.10548019940205561,
#      'n_estimators': 179,
#      'max_depth': 6,
#      'subsample': 0.7874459483961107,
#      'colsample_bytree': 0.9359840421044765},
#     {'objective': 'reg:squarederror',
#      'lambda': 0.005610204576382474,
#      'learning_rate': 0.01571876388948241,
#      'n_estimators': 194,
#      'max_depth': 10,
#      'subsample': 0.622086091542503,
#      'colsample_bytree': 0.9579219769567477},
#     {'objective': 'reg:squarederror',
#      'lambda': 0.2141549249607652,
#      'learning_rate': 0.04036810717031493,
#      'n_estimators': 200,
#      'max_depth': 10,
#      'subsample': 0.8122730811236298,
#      'colsample_bytree': 0.9036453635842872},
#     {'objective': 'reg:squarederror',
#      'lambda': 0.1320006797696215,
#      'learning_rate': 0.05810955233056761,
#      'n_estimators': 297,
#      'max_depth': 8,
#      'subsample': 0.9838095353134868,
#      'colsample_bytree': 0.9164641254810653},
#     {'objective': 'reg:squarederror',
#      'lambda': 0.00165731037052503,
#      'learning_rate': 0.11437227012871984,
#      'n_estimators': 93,
#      'max_depth': 7,
#      'subsample': 0.5495836076340757,
#      'colsample_bytree': 0.702089979440168}]}},
#  '44959': {'XGBoost': {'score_train': [0.06545617431402206,
#     0.13400648534297943,
#     0.09197025746107101,
#     0.06494702398777008,
#     0.07178261131048203],
#    'score_test': [0.2807149589061737,
#     0.2895848751068115,
#     0.2766687870025635,
#     0.252706378698349,
#     0.22804436087608337],
#    't_fit': [0.05550316599965299,
#     0.0527608729998974,
#     0.215746823999325,
#     0.22349526899961347,
#     0.2217137649995493],
#    't_inference': [0.0016272209995804587,
#     0.0019592650005506584,
#     0.0030367859999387292,
#     0.0035525989997040597,
#     0.005258950000097684],
#    'hyperparams': [{'objective': 'reg:squarederror',
#      'lambda': 0.027486172826441117,
#      'learning_rate': 0.20624709869755437,
#      'n_estimators': 72,
#      'max_depth': 7,
#      'subsample': 0.7423580745094693,
#      'colsample_bytree': 0.5221873711491241},
#     {'objective': 'reg:squarederror',
#      'lambda': 0.009568241003476868,
#      'learning_rate': 0.18882268690221676,
#      'n_estimators': 214,
#      'max_depth': 3,
#      'subsample': 0.7414879439481143,
#      'colsample_bytree': 0.9458855071103944},
#     {'objective': 'reg:squarederror',
#      'lambda': 0.003791199721383897,
#      'learning_rate': 0.021477534672509426,
#      'n_estimators': 186,
#      'max_depth': 8,
#      'subsample': 0.5681049504991935,
#      'colsample_bytree': 0.7045392410340755},
#     {'objective': 'reg:squarederror',
#      'lambda': 4.097816585494131,
#      'learning_rate': 0.14302123585377594,
#      'n_estimators': 235,
#      'max_depth': 8,
#      'subsample': 0.6029669544031555,
#      'colsample_bytree': 0.7320094496849403},
#     {'objective': 'reg:squarederror',
#      'lambda': 0.5493569455577606,
#      'learning_rate': 0.06424387591365195,
#      'n_estimators': 294,
#      'max_depth': 7,
#      'subsample': 0.6386165448773796,
#      'colsample_bytree': 0.5602703675738538}]}}}

# %%
# TODO ABLATION STUDY experiement with default f(x_t) f( [x_t, x_0] ), [f(x_t), x_0], and [ f_1(x_t) f_2(x_0)]
# TODO ablation study for scalar/diag/dense DELTA
# TODO GradientRFBoost for binary classification

# %% [markdown]
# Regression Models

# %% [markdown]
# * XGBoost (trees)
# * Ridge Regression
# * E2E ResNet
#
# for feat_type in [SWIM, Gaussian iid]:
# * Random Feature ResNet
# * Greedy RandFeatBoost
# * Gradient RandFeatBoost
# * (optional) Greedy SGD ResNetBoost

# %% [markdown]
# Classification differences:

# %% [markdown]
# * Ridge -> Logistic Regression
# * No Greeedy RFBoost

# %% [markdown]
# # SCALAR VS DIAG VS DENSE
#
# only works for regression. Should i have a separate graph for this?
